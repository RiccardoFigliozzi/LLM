# %% [markdown]
# # Project: RAG - Q&A on Private Documents using LangChain
#
# This notebook uses **the latest versions** of the OpenAI and LangChain libraries.

# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
os.environ["HUGGINGFACEHUB_API_TOKEN"] = os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %% [markdown]
# ### Loading Documents

# %%
# loading PDF, DOCX and TXT files as LangChain Documents
def load_document(file):
    import os
    name, extension = os.path.splitext(file)

    if extension == '.pdf':
        from langchain.document_loaders import PyPDFLoader
        print(f'Loading {file}')
        loader = PyPDFLoader(file)
    elif extension == '.docx':
        from langchain.document_loaders import Docx2txtLoader
        print(f'Loading {file}')
        loader = Docx2txtLoader(file)
    elif extension == '.txt':
        from langchain.document_loaders import TextLoader
        loader = TextLoader(file)
    elif extension == '.csv':
        from langchain_community.document_loaders.csv_loader import CSVLoader
        loader = CSVLoader(file)
    else:
        print('Document format is not supported!')
        return None

    data = loader.load()
    return data

# %%
# wikipedia
def load_from_wikipedia(query, lang='en', load_max_docs=2):
    from langchain.document_loaders import WikipediaLoader
    loader = WikipediaLoader(query=query, lang=lang, load_max_docs=load_max_docs)
    data = loader.load()
    return data

# %% [markdown]
# ### Chunking Data

# %%
def chunk_data(data, chunk_size=256):
    from langchain.text_splitter import RecursiveCharacterTextSplitter
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=0)
    chunks = text_splitter.split_documents(data)
    return chunks

# %% [markdown]
# ### Calculating Cost

# %%
def print_embedding_cost(texts):
    import tiktoken
    enc = tiktoken.encoding_for_model('text-embedding-3-small')
    total_tokens = sum([len(enc.encode(page.page_content)) for page in texts])
    # check prices here: https://openai.com/pricing
    print(f'Total Tokens: {total_tokens}')
    print(f'Embedding Cost in USD: {total_tokens / 1000 * 0.00002:.6f}')

# %% [markdown]
# ### Embedding and Uploading to a Vector Database (Chroma DB)

# %%
def create_embeddings_chroma(chunks, persist_directory='./chroma_db'):
    from langchain.vectorstores import Chroma
    from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings

    embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=os.getenv("HUGGINGFACEHUB_API_TOKEN"), model_name="sentence-transformers/all-MiniLM-l6-v2"
) 

    # Create a Chroma vector store using the provided text chunks and embedding model, 
    # configuring it to save data to the specified directory 
    vector_store = Chroma.from_documents(chunks, embeddings, persist_directory=persist_directory) 

    return vector_store  # Return the created vector store

# %%
def load_embeddings_chroma(persist_directory='./chroma_db'):
    from langchain.vectorstores import Chroma
    from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings

    embeddings = HuggingFaceInferenceAPIEmbeddings(api_key=os.getenv("HUGGINGFACEHUB_API_TOKEN"), 
                                                   model_name="sentence-transformers/all-MiniLM-l6-v2") 

    # Load a Chroma vector store from the specified directory, using the provided embedding function
    vector_store = Chroma(persist_directory=persist_directory, embedding_function=embeddings) 

    return vector_store  # Return the loaded vector store

# %% [markdown]
# ### Asking and Getting Answers

# %%
def ask_and_get_answer(vector_store, q, k=18):
    from langchain.chains import RetrievalQA
    from langchain_community.llms import HuggingFaceEndpoint

    repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

    llm = HuggingFaceEndpoint(
        repo_id=repo_id, max_length=128, temperature=0.1,
    )

    retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': k})

    chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever, return_source_documents=True)

    answer = chain.invoke(q)
    return answer

# %% [markdown]
# ### Running Code

# %%
# Loading the pdf document into LangChain 
data = load_document('files/mistral.pdf')

# Splitting the document into chunks
chunks = chunk_data(data, chunk_size=256)

# Creating a Chroma vector store using the provided text chunks and embedding model (default is text-embedding-3-small)
vector_store = create_embeddings_chroma(chunks)
# Out:
# Loading files/mistral.pdf

# %%
chunks
# Out:
# [Document(page_content="NOME PROVINCIA (ISTAT): Livorno\nCODICE NUTS 3 2021: ITI16\nCODICE PROVINCIA ISTAT (STORICO): 049\nDENOMINAZIONE CORRENTE: Livorno\nVALORE: 65.53\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 0}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 0}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Massa-Carrara\nCODICE NUTS 3 2021: ITI11\nCODICE PROVINCIA ISTAT (STORICO): 045\nDENOMINAZIONE CORRENTE: Massa-Carrara\nVALORE: 62.686\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 1}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 1}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Cagliari\nCODICE NUTS 3 2021: ITG2F\nCODICE PROVINCIA ISTAT (STORICO): 092\nDENOMINAZIONE CORRENTE: Cagliari\nVALORE: 61.924\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 2}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 2}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Valle d'Aosta/Vallée d'Aoste\nCODICE NUTS 3 2021: ITC20\nCODICE PROVINCIA ISTAT (STORICO): 007\nDENOMINAZIONE CORRENTE: Aosta\nVALORE: 61.681\nINDICATORE: Popolazione con crediti attivi", metadata={'source': 'files/vita.csv', 'row': 3}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 3}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lodi\nCODICE NUTS 3 2021: ITC49\nCODICE PROVINCIA ISTAT (STORICO): 098\nDENOMINAZIONE CORRENTE: Lodi\nVALORE: 61.133\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 4}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 4}),
#  Document(page_content='NOME PROVINCIA (ISTAT): La Spezia\nCODICE NUTS 3 2021: ITC34\nCODICE PROVINCIA ISTAT (STORICO): 011\nDENOMINAZIONE CORRENTE: La Spezia\nVALORE: 60.89\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 5}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 5}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Pisa\nCODICE NUTS 3 2021: ITI17\nCODICE PROVINCIA ISTAT (STORICO): 050\nDENOMINAZIONE CORRENTE: Pisa\nVALORE: 60.602\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 6}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 6}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Roma\nCODICE NUTS 3 2021: ITI43\nCODICE PROVINCIA ISTAT (STORICO): 058\nDENOMINAZIONE CORRENTE: Roma\nVALORE: 59.569\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 7}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 7}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Torino\nCODICE NUTS 3 2021: ITC11\nCODICE PROVINCIA ISTAT (STORICO): 001\nDENOMINAZIONE CORRENTE: Torino\nVALORE: 59.139\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 8}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 8}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Novara\nCODICE NUTS 3 2021: ITC15\nCODICE PROVINCIA ISTAT (STORICO): 003\nDENOMINAZIONE CORRENTE: Novara\nVALORE: 58.988\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 9}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 9}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Varese\nCODICE NUTS 3 2021: ITC41\nCODICE PROVINCIA ISTAT (STORICO): 012\nDENOMINAZIONE CORRENTE: Varese\nVALORE: 58.671\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 10}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 10}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Latina\nCODICE NUTS 3 2021: ITI44\nCODICE PROVINCIA ISTAT (STORICO): 059\nDENOMINAZIONE CORRENTE: Latina\nVALORE: 58.652\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 11}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 11}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Pavia\nCODICE NUTS 3 2021: ITC48\nCODICE PROVINCIA ISTAT (STORICO): 018\nDENOMINAZIONE CORRENTE: Pavia\nVALORE: 58.644\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 12}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 12}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Prato\nCODICE NUTS 3 2021: ITI15\nCODICE PROVINCIA ISTAT (STORICO): 100\nDENOMINAZIONE CORRENTE: Prato\nVALORE: 58.219\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 13}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 13}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Pistoia\nCODICE NUTS 3 2021: ITI13\nCODICE PROVINCIA ISTAT (STORICO): 047\nDENOMINAZIONE CORRENTE: Pistoia\nVALORE: 58.185\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 14}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 14}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Sassari\nCODICE NUTS 3 2021: ITG2D\nCODICE PROVINCIA ISTAT (STORICO): 090\nDENOMINAZIONE CORRENTE: Sassari\nVALORE: 58.107\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 15}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 15}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Monza e della Brianza\nCODICE NUTS 3 2021: ITC4D\nCODICE PROVINCIA ISTAT (STORICO): 108\nDENOMINAZIONE CORRENTE: Monza e Brianza\nVALORE: 56.766\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 16}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 16}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Vercelli\nCODICE NUTS 3 2021: ITC12\nCODICE PROVINCIA ISTAT (STORICO): 002\nDENOMINAZIONE CORRENTE: Vercelli\nVALORE: 56.631\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 17}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 17}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lucca\nCODICE NUTS 3 2021: ITI12\nCODICE PROVINCIA ISTAT (STORICO): 046\nDENOMINAZIONE CORRENTE: Lucca\nVALORE: 56.307\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 18}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 18}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Gorizia\nCODICE NUTS 3 2021: ITH43\nCODICE PROVINCIA ISTAT (STORICO): 031\nDENOMINAZIONE CORRENTE: Gorizia\nVALORE: 56.262\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 19}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 19}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Viterbo\nCODICE NUTS 3 2021: ITI41\nCODICE PROVINCIA ISTAT (STORICO): 056\nDENOMINAZIONE CORRENTE: Viterbo\nVALORE: 55.977\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 20}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 20}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Siracusa\nCODICE NUTS 3 2021: ITG19\nCODICE PROVINCIA ISTAT (STORICO): 089\nDENOMINAZIONE CORRENTE: Siracusa\nVALORE: 55.521\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 21}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 21}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Frosinone\nCODICE NUTS 3 2021: ITI45\nCODICE PROVINCIA ISTAT (STORICO): 060\nDENOMINAZIONE CORRENTE: Frosinone\nVALORE: 55.045\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 22}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 22}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Palermo\nCODICE NUTS 3 2021: ITG12\nCODICE PROVINCIA ISTAT (STORICO): 082\nDENOMINAZIONE CORRENTE: Palermo\nVALORE: 54.986\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 23}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 23}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Grosseto\nCODICE NUTS 3 2021: ITI1A\nCODICE PROVINCIA ISTAT (STORICO): 053\nDENOMINAZIONE CORRENTE: Grosseto\nVALORE: 54.961\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 24}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 24}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Firenze\nCODICE NUTS 3 2021: ITI14\nCODICE PROVINCIA ISTAT (STORICO): 048\nDENOMINAZIONE CORRENTE: Firenze\nVALORE: 54.904\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 25}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 25}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Parma\nCODICE NUTS 3 2021: ITH52\nCODICE PROVINCIA ISTAT (STORICO): 034\nDENOMINAZIONE CORRENTE: Parma\nVALORE: 54.875\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 26}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 26}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Perugia\nCODICE NUTS 3 2021: ITI21\nCODICE PROVINCIA ISTAT (STORICO): 054\nDENOMINAZIONE CORRENTE: Perugia\nVALORE: 54.789\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 27}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 27}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Pordenone\nCODICE NUTS 3 2021: ITH41\nCODICE PROVINCIA ISTAT (STORICO): 093\nDENOMINAZIONE CORRENTE: Pordenone\nVALORE: 54.712\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 28}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 28}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Milano\nCODICE NUTS 3 2021: ITC4C\nCODICE PROVINCIA ISTAT (STORICO): 015\nDENOMINAZIONE CORRENTE: Milano\nVALORE: 54.545\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 29}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 29}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Biella\nCODICE NUTS 3 2021: ITC13\nCODICE PROVINCIA ISTAT (STORICO): 096\nDENOMINAZIONE CORRENTE: Biella\nVALORE: 54.529\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 30}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 30}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Bari\nCODICE NUTS 3 2021: ITF47\nCODICE PROVINCIA ISTAT (STORICO): 072\nDENOMINAZIONE CORRENTE: Bari\nVALORE: 54.356\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 31}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 31}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Pescara\nCODICE NUTS 3 2021: ITF13\nCODICE PROVINCIA ISTAT (STORICO): 068\nDENOMINAZIONE CORRENTE: Pescara\nVALORE: 54.321\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 32}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 32}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Asti\nCODICE NUTS 3 2021: ITC17\nCODICE PROVINCIA ISTAT (STORICO): 005\nDENOMINAZIONE CORRENTE: Asti\nVALORE: 54.182\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 33}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 33}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Taranto\nCODICE NUTS 3 2021: ITF43\nCODICE PROVINCIA ISTAT (STORICO): 073\nDENOMINAZIONE CORRENTE: Taranto\nVALORE: 54.18\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 34}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 34}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Ancona\nCODICE NUTS 3 2021: ITI32\nCODICE PROVINCIA ISTAT (STORICO): 042\nDENOMINAZIONE CORRENTE: Ancona\nVALORE: 54.154\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 35}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 35}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Modena\nCODICE NUTS 3 2021: ITH54\nCODICE PROVINCIA ISTAT (STORICO): 036\nDENOMINAZIONE CORRENTE: Modena\nVALORE: 54.08\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 36}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 36}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Venezia\nCODICE NUTS 3 2021: ITH35\nCODICE PROVINCIA ISTAT (STORICO): 027\nDENOMINAZIONE CORRENTE: Venezia\nVALORE: 53.801\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 37}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 37}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Oristano\nCODICE NUTS 3 2021: ITG2G\nCODICE PROVINCIA ISTAT (STORICO): 095\nDENOMINAZIONE CORRENTE: Oristano\nVALORE: 53.78\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 38}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 38}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Arezzo\nCODICE NUTS 3 2021: ITI18\nCODICE PROVINCIA ISTAT (STORICO): 051\nDENOMINAZIONE CORRENTE: Arezzo\nVALORE: 53.72\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 39}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 39}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Cremona\nCODICE NUTS 3 2021: ITC4A\nCODICE PROVINCIA ISTAT (STORICO): 019\nDENOMINAZIONE CORRENTE: Cremona\nVALORE: 53.569\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 40}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 40}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Ragusa\nCODICE NUTS 3 2021: ITG18\nCODICE PROVINCIA ISTAT (STORICO): 088\nDENOMINAZIONE CORRENTE: Ragusa\nVALORE: 53.563\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 41}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 41}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Como\nCODICE NUTS 3 2021: ITC42\nCODICE PROVINCIA ISTAT (STORICO): 013\nDENOMINAZIONE CORRENTE: Como\nVALORE: 53.46\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 42}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 42}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Piacenza\nCODICE NUTS 3 2021: ITH51\nCODICE PROVINCIA ISTAT (STORICO): 033\nDENOMINAZIONE CORRENTE: Piacenza\nVALORE: 53.373\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 43}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 43}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Siena\nCODICE NUTS 3 2021: ITI19\nCODICE PROVINCIA ISTAT (STORICO): 052\nDENOMINAZIONE CORRENTE: Siena\nVALORE: 53.349\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 44}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 44}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Catania\nCODICE NUTS 3 2021: ITG17\nCODICE PROVINCIA ISTAT (STORICO): 087\nDENOMINAZIONE CORRENTE: Catania\nVALORE: 53.311\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 45}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 45}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Ravenna\nCODICE NUTS 3 2021: ITH57\nCODICE PROVINCIA ISTAT (STORICO): 039\nDENOMINAZIONE CORRENTE: Ravenna\nVALORE: 53.263\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 46}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 46}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Bologna\nCODICE NUTS 3 2021: ITH55\nCODICE PROVINCIA ISTAT (STORICO): 037\nDENOMINAZIONE CORRENTE: Bologna\nVALORE: 52.83\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 47}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 47}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Pesaro e Urbino\nCODICE NUTS 3 2021: ITI31\nCODICE PROVINCIA ISTAT (STORICO): 041\nDENOMINAZIONE CORRENTE: Pesaro e Urbino\nVALORE: 52.797\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 48}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 48}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Padova\nCODICE NUTS 3 2021: ITH36\nCODICE PROVINCIA ISTAT (STORICO): 028\nDENOMINAZIONE CORRENTE: Padova\nVALORE: 52.63\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 49}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 49}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Reggio nell'Emilia\nCODICE NUTS 3 2021: ITH53\nCODICE PROVINCIA ISTAT (STORICO): 035\nDENOMINAZIONE CORRENTE: Reggio Emilia\nVALORE: 52.618\nINDICATORE: Popolazione con crediti attivi", metadata={'source': 'files/vita.csv', 'row': 50}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 50}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Alessandria\nCODICE NUTS 3 2021: ITC18\nCODICE PROVINCIA ISTAT (STORICO): 006\nDENOMINAZIONE CORRENTE: Alessandria\nVALORE: 52.506\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 51}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 51}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Rovigo\nCODICE NUTS 3 2021: ITH37\nCODICE PROVINCIA ISTAT (STORICO): 029\nDENOMINAZIONE CORRENTE: Rovigo\nVALORE: 52.493\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 52}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 52}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Terni\nCODICE NUTS 3 2021: ITI22\nCODICE PROVINCIA ISTAT (STORICO): 055\nDENOMINAZIONE CORRENTE: Terni\nVALORE: 52.439\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 53}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 53}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Ferrara\nCODICE NUTS 3 2021: ITH56\nCODICE PROVINCIA ISTAT (STORICO): 038\nDENOMINAZIONE CORRENTE: Ferrara\nVALORE: 52.338\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 54}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 54}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Savona\nCODICE NUTS 3 2021: ITC32\nCODICE PROVINCIA ISTAT (STORICO): 009\nDENOMINAZIONE CORRENTE: Savona\nVALORE: 51.892\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 55}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 55}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Brindisi\nCODICE NUTS 3 2021: ITF44\nCODICE PROVINCIA ISTAT (STORICO): 074\nDENOMINAZIONE CORRENTE: Brindisi\nVALORE: 51.84\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 56}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 56}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Genova\nCODICE NUTS 3 2021: ITC33\nCODICE PROVINCIA ISTAT (STORICO): 010\nDENOMINAZIONE CORRENTE: Genova\nVALORE: 51.587\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 57}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 57}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Teramo\nCODICE NUTS 3 2021: ITF12\nCODICE PROVINCIA ISTAT (STORICO): 067\nDENOMINAZIONE CORRENTE: Teramo\nVALORE: 51.562\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 58}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 58}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Verbano-Cusio-Ossola\nCODICE NUTS 3 2021: ITC14\nCODICE PROVINCIA ISTAT (STORICO): 103\nDENOMINAZIONE CORRENTE: Verbano-Cusio-Ossola\nVALORE: 51.524\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 59}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 59}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Sud Sardegna\nCODICE NUTS 3 2021: ITG2H\nCODICE PROVINCIA ISTAT (STORICO): 111\nDENOMINAZIONE CORRENTE: Sud Sardegna\nVALORE: 51.491\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 60}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 60}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Ascoli Piceno\nCODICE NUTS 3 2021: ITI34\nCODICE PROVINCIA ISTAT (STORICO): 044\nDENOMINAZIONE CORRENTE: Ascoli Piceno\nVALORE: 51.461\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 61}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 61}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Rieti\nCODICE NUTS 3 2021: ITI42\nCODICE PROVINCIA ISTAT (STORICO): 057\nDENOMINAZIONE CORRENTE: Rieti\nVALORE: 51.456\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 62}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 62}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Trapani\nCODICE NUTS 3 2021: ITG11\nCODICE PROVINCIA ISTAT (STORICO): 081\nDENOMINAZIONE CORRENTE: Trapani\nVALORE: 51.39\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 63}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 63}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Trieste\nCODICE NUTS 3 2021: ITH44\nCODICE PROVINCIA ISTAT (STORICO): 032\nDENOMINAZIONE CORRENTE: Trieste\nVALORE: 51.069\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 64}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 64}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Verona\nCODICE NUTS 3 2021: ITH31\nCODICE PROVINCIA ISTAT (STORICO): 023\nDENOMINAZIONE CORRENTE: Verona\nVALORE: 51.011\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 65}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 65}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Treviso\nCODICE NUTS 3 2021: ITH34\nCODICE PROVINCIA ISTAT (STORICO): 026\nDENOMINAZIONE CORRENTE: Treviso\nVALORE: 50.654\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 66}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 66}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Forlì-Cesena\nCODICE NUTS 3 2021: ITH58\nCODICE PROVINCIA ISTAT (STORICO): 040\nDENOMINAZIONE CORRENTE: Forlì-Cesena\nVALORE: 50.451\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 67}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 67}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Mantova\nCODICE NUTS 3 2021: ITC4B\nCODICE PROVINCIA ISTAT (STORICO): 020\nDENOMINAZIONE CORRENTE: Mantova\nVALORE: 50.407\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 68}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 68}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Chieti\nCODICE NUTS 3 2021: ITF14\nCODICE PROVINCIA ISTAT (STORICO): 069\nDENOMINAZIONE CORRENTE: Chieti\nVALORE: 50.015\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 69}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 69}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Udine\nCODICE NUTS 3 2021: ITH42\nCODICE PROVINCIA ISTAT (STORICO): 030\nDENOMINAZIONE CORRENTE: Udine\nVALORE: 49.891\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 70}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 70}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Crotone\nCODICE NUTS 3 2021: ITF62\nCODICE PROVINCIA ISTAT (STORICO): 101\nDENOMINAZIONE CORRENTE: Crotone\nVALORE: 49.872\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 71}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 71}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Imperia\nCODICE NUTS 3 2021: ITC31\nCODICE PROVINCIA ISTAT (STORICO): 008\nDENOMINAZIONE CORRENTE: Imperia\nVALORE: 49.828\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 72}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 72}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Brescia\nCODICE NUTS 3 2021: ITC47\nCODICE PROVINCIA ISTAT (STORICO): 017\nDENOMINAZIONE CORRENTE: Brescia\nVALORE: 49.668\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 73}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 73}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Vicenza\nCODICE NUTS 3 2021: ITH32\nCODICE PROVINCIA ISTAT (STORICO): 024\nDENOMINAZIONE CORRENTE: Vicenza\nVALORE: 49.579\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 74}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 74}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Bergamo\nCODICE NUTS 3 2021: ITC46\nCODICE PROVINCIA ISTAT (STORICO): 016\nDENOMINAZIONE CORRENTE: Bergamo\nVALORE: 48.836\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 75}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 75}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Catanzaro\nCODICE NUTS 3 2021: ITF63\nCODICE PROVINCIA ISTAT (STORICO): 079\nDENOMINAZIONE CORRENTE: Catanzaro\nVALORE: 48.363\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 76}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 76}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Barletta-Andria-Trani\nCODICE NUTS 3 2021: ITF48\nCODICE PROVINCIA ISTAT (STORICO): 110\nDENOMINAZIONE CORRENTE: Barletta-Andria-Trani\nVALORE: 48.229\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 77}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 77}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Macerata\nCODICE NUTS 3 2021: ITI33\nCODICE PROVINCIA ISTAT (STORICO): 043\nDENOMINAZIONE CORRENTE: Macerata\nVALORE: 48.127\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 78}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 78}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Napoli\nCODICE NUTS 3 2021: ITF33\nCODICE PROVINCIA ISTAT (STORICO): 063\nDENOMINAZIONE CORRENTE: Napoli\nVALORE: 48.085\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 79}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 79}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Reggio Calabria\nCODICE NUTS 3 2021: ITF65\nCODICE PROVINCIA ISTAT (STORICO): 080\nDENOMINAZIONE CORRENTE: Reggio Calabria\nVALORE: 48.04\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 80}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 80}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Messina\nCODICE NUTS 3 2021: ITG13\nCODICE PROVINCIA ISTAT (STORICO): 083\nDENOMINAZIONE CORRENTE: Messina\nVALORE: 47.863\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 81}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 81}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lecce\nCODICE NUTS 3 2021: ITF45\nCODICE PROVINCIA ISTAT (STORICO): 075\nDENOMINAZIONE CORRENTE: Lecce\nVALORE: 47.5\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 82}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 82}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Nuoro\nCODICE NUTS 3 2021: ITG2E\nCODICE PROVINCIA ISTAT (STORICO): 091\nDENOMINAZIONE CORRENTE: Nuoro\nVALORE: 47.456\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 83}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 83}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lecco\nCODICE NUTS 3 2021: ITC43\nCODICE PROVINCIA ISTAT (STORICO): 097\nDENOMINAZIONE CORRENTE: Lecco\nVALORE: 47.016\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 84}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 84}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Caserta\nCODICE NUTS 3 2021: ITF31\nCODICE PROVINCIA ISTAT (STORICO): 061\nDENOMINAZIONE CORRENTE: Caserta\nVALORE: 47.0\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 85}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 85}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Campobasso\nCODICE NUTS 3 2021: ITF22\nCODICE PROVINCIA ISTAT (STORICO): 070\nDENOMINAZIONE CORRENTE: Campobasso\nVALORE: 46.887\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 86}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 86}),
#  Document(page_content="NOME PROVINCIA (ISTAT): L'Aquila\nCODICE NUTS 3 2021: ITF11\nCODICE PROVINCIA ISTAT (STORICO): 066\nDENOMINAZIONE CORRENTE: L'Aquila\nVALORE: 46.56\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 87}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 87}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Rimini\nCODICE NUTS 3 2021: ITH59\nCODICE PROVINCIA ISTAT (STORICO): 099\nDENOMINAZIONE CORRENTE: Rimini\nVALORE: 46.002\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 88}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 88}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Fermo\nCODICE NUTS 3 2021: ITI35\nCODICE PROVINCIA ISTAT (STORICO): 109\nDENOMINAZIONE CORRENTE: Fermo\nVALORE: 45.641\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 89}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 89}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Foggia\nCODICE NUTS 3 2021: ITF46\nCODICE PROVINCIA ISTAT (STORICO): 071\nDENOMINAZIONE CORRENTE: Foggia\nVALORE: 45.385\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 90}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 90}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Cuneo\nCODICE NUTS 3 2021: ITC16\nCODICE PROVINCIA ISTAT (STORICO): 004\nDENOMINAZIONE CORRENTE: Cuneo\nVALORE: 45.258\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 91}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 91}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Caltanissetta\nCODICE NUTS 3 2021: ITG15\nCODICE PROVINCIA ISTAT (STORICO): 085\nDENOMINAZIONE CORRENTE: Caltanissetta\nVALORE: 44.973\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 92}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 92}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Isernia\nCODICE NUTS 3 2021: ITF21\nCODICE PROVINCIA ISTAT (STORICO): 094\nDENOMINAZIONE CORRENTE: Isernia\nVALORE: 44.637\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 93}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 93}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Cosenza\nCODICE NUTS 3 2021: ITF61\nCODICE PROVINCIA ISTAT (STORICO): 078\nDENOMINAZIONE CORRENTE: Cosenza\nVALORE: 43.707\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 94}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 94}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Belluno\nCODICE NUTS 3 2021: ITH33\nCODICE PROVINCIA ISTAT (STORICO): 025\nDENOMINAZIONE CORRENTE: Belluno\nVALORE: 43.618\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 95}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 95}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Salerno\nCODICE NUTS 3 2021: ITF35\nCODICE PROVINCIA ISTAT (STORICO): 065\nDENOMINAZIONE CORRENTE: Salerno\nVALORE: 43.585\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 96}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 96}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Avellino\nCODICE NUTS 3 2021: ITF34\nCODICE PROVINCIA ISTAT (STORICO): 064\nDENOMINAZIONE CORRENTE: Avellino\nVALORE: 42.142\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 97}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 97}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Agrigento\nCODICE NUTS 3 2021: ITG14\nCODICE PROVINCIA ISTAT (STORICO): 084\nDENOMINAZIONE CORRENTE: Agrigento\nVALORE: 42.009\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 98}),
#  Document(page_content="UNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti\nRIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif", metadata={'source': 'files/vita.csv', 'row': 98}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Potenza\nCODICE NUTS 3 2021: ITF51\nCODICE PROVINCIA ISTAT (STORICO): 076\nDENOMINAZIONE CORRENTE: Potenza\nVALORE: 41.682\nINDICATORE: Popolazione con crediti attivi\nUNITA' DI MISURA: In percentuale sul totale dei maggiorenni residenti", metadata={'source': 'files/vita.csv', 'row': 99}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a giugno 2023\nFONTE ORIGINALE: Crif', metadata={'source': 'files/vita.csv', 'row': 99}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Vibo Valentia\nCODICE NUTS 3 2021: ITF64\nCODICE PROVINCIA ISTAT (STORICO): 102\nDENOMINAZIONE CORRENTE: Vibo Valentia\nVALORE: 41.584\nINDICATORE: Popolazione con crediti attivi', metadata={'source': 'files/vita.csv', 'row': 100}),
# ...
#  Document(page_content="NOME PROVINCIA (ISTAT): Pistoia\nCODICE NUTS 3 2021: ITI13\nCODICE PROVINCIA ISTAT (STORICO): 047\nDENOMINAZIONE CORRENTE: Pistoia\nVALORE: 7.866\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 467}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 467}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Firenze\nCODICE NUTS 3 2021: ITI14\nCODICE PROVINCIA ISTAT (STORICO): 048\nDENOMINAZIONE CORRENTE: Firenze\nVALORE: 7.897\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 468}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 468}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Milano\nCODICE NUTS 3 2021: ITC4C\nCODICE PROVINCIA ISTAT (STORICO): 015\nDENOMINAZIONE CORRENTE: Milano\nVALORE: 7.914\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 469}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 469}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lodi\nCODICE NUTS 3 2021: ITC49\nCODICE PROVINCIA ISTAT (STORICO): 098\nDENOMINAZIONE CORRENTE: Lodi\nVALORE: 8.017\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 470}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 470}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Gorizia\nCODICE NUTS 3 2021: ITH43\nCODICE PROVINCIA ISTAT (STORICO): 031\nDENOMINAZIONE CORRENTE: Gorizia\nVALORE: 8.025\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 471}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 471}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Trieste\nCODICE NUTS 3 2021: ITH44\nCODICE PROVINCIA ISTAT (STORICO): 032\nDENOMINAZIONE CORRENTE: Trieste\nVALORE: 8.049\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 472}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 472}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Asti\nCODICE NUTS 3 2021: ITC17\nCODICE PROVINCIA ISTAT (STORICO): 005\nDENOMINAZIONE CORRENTE: Asti\nVALORE: 8.095\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 473}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 473}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Torino\nCODICE NUTS 3 2021: ITC11\nCODICE PROVINCIA ISTAT (STORICO): 001\nDENOMINAZIONE CORRENTE: Torino\nVALORE: 8.339\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 474}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 474}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Arezzo\nCODICE NUTS 3 2021: ITI18\nCODICE PROVINCIA ISTAT (STORICO): 051\nDENOMINAZIONE CORRENTE: Arezzo\nVALORE: 8.563\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 475}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 475}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Lucca\nCODICE NUTS 3 2021: ITI12\nCODICE PROVINCIA ISTAT (STORICO): 046\nDENOMINAZIONE CORRENTE: Lucca\nVALORE: 8.577\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 476}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 476}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Genova\nCODICE NUTS 3 2021: ITC33\nCODICE PROVINCIA ISTAT (STORICO): 010\nDENOMINAZIONE CORRENTE: Genova\nVALORE: 8.668\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 477}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 477}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Siena\nCODICE NUTS 3 2021: ITI19\nCODICE PROVINCIA ISTAT (STORICO): 052\nDENOMINAZIONE CORRENTE: Siena\nVALORE: 8.732\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 478}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 478}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Savona\nCODICE NUTS 3 2021: ITC32\nCODICE PROVINCIA ISTAT (STORICO): 009\nDENOMINAZIONE CORRENTE: Savona\nVALORE: 8.876\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 479}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 479}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Alessandria\nCODICE NUTS 3 2021: ITC18\nCODICE PROVINCIA ISTAT (STORICO): 006\nDENOMINAZIONE CORRENTE: Alessandria\nVALORE: 8.898\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 480}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 480}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Piacenza\nCODICE NUTS 3 2021: ITH51\nCODICE PROVINCIA ISTAT (STORICO): 033\nDENOMINAZIONE CORRENTE: Piacenza\nVALORE: 9.035\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 481}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 481}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Rovigo\nCODICE NUTS 3 2021: ITH37\nCODICE PROVINCIA ISTAT (STORICO): 029\nDENOMINAZIONE CORRENTE: Rovigo\nVALORE: 9.424\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 482}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 482}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Perugia\nCODICE NUTS 3 2021: ITI21\nCODICE PROVINCIA ISTAT (STORICO): 054\nDENOMINAZIONE CORRENTE: Perugia\nVALORE: 9.514\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 483}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 483}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Imperia\nCODICE NUTS 3 2021: ITC31\nCODICE PROVINCIA ISTAT (STORICO): 008\nDENOMINAZIONE CORRENTE: Imperia\nVALORE: 9.587\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 484}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 484}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Ascoli Piceno\nCODICE NUTS 3 2021: ITI34\nCODICE PROVINCIA ISTAT (STORICO): 044\nDENOMINAZIONE CORRENTE: Ascoli Piceno\nVALORE: 10.143\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 485}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 485}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Pavia\nCODICE NUTS 3 2021: ITC48\nCODICE PROVINCIA ISTAT (STORICO): 018\nDENOMINAZIONE CORRENTE: Pavia\nVALORE: 10.49\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 486}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 486}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Massa-Carrara\nCODICE NUTS 3 2021: ITI11\nCODICE PROVINCIA ISTAT (STORICO): 045\nDENOMINAZIONE CORRENTE: Massa-Carrara\nVALORE: 10.739\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 487}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 487}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Nuoro\nCODICE NUTS 3 2021: ITG2E\nCODICE PROVINCIA ISTAT (STORICO): 091\nDENOMINAZIONE CORRENTE: Nuoro\nVALORE: 10.75\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 488}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 488}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Grosseto\nCODICE NUTS 3 2021: ITI1A\nCODICE PROVINCIA ISTAT (STORICO): 053\nDENOMINAZIONE CORRENTE: Grosseto\nVALORE: 10.787\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 489}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 489}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Bari\nCODICE NUTS 3 2021: ITF47\nCODICE PROVINCIA ISTAT (STORICO): 072\nDENOMINAZIONE CORRENTE: Bari\nVALORE: 10.904\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 490}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 490}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Viterbo\nCODICE NUTS 3 2021: ITI41\nCODICE PROVINCIA ISTAT (STORICO): 056\nDENOMINAZIONE CORRENTE: Viterbo\nVALORE: 10.94\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 491}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 491}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Matera\nCODICE NUTS 3 2021: ITF52\nCODICE PROVINCIA ISTAT (STORICO): 077\nDENOMINAZIONE CORRENTE: Matera\nVALORE: 11.276\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 492}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 492}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Terni\nCODICE NUTS 3 2021: ITI22\nCODICE PROVINCIA ISTAT (STORICO): 055\nDENOMINAZIONE CORRENTE: Terni\nVALORE: 11.32\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 493}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 493}),
#  Document(page_content='NOME PROVINCIA (ISTAT): La Spezia\nCODICE NUTS 3 2021: ITC34\nCODICE PROVINCIA ISTAT (STORICO): 011\nDENOMINAZIONE CORRENTE: La Spezia\nVALORE: 11.537\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 494}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 494}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Potenza\nCODICE NUTS 3 2021: ITF51\nCODICE PROVINCIA ISTAT (STORICO): 076\nDENOMINAZIONE CORRENTE: Potenza\nVALORE: 11.656\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 495}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 495}),
#  Document(page_content="NOME PROVINCIA (ISTAT): Livorno\nCODICE NUTS 3 2021: ITI16\nCODICE PROVINCIA ISTAT (STORICO): 049\nDENOMINAZIONE CORRENTE: Livorno\nVALORE: 12.134\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni\nUNITA' DI MISURA: % delle fatture commerciali ai fornitori", metadata={'source': 'files/vita.csv', 'row': 496}),
#  Document(page_content='RIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis', metadata={'source': 'files/vita.csv', 'row': 496}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Sud Sardegna\nCODICE NUTS 3 2021: ITG2H\nCODICE PROVINCIA ISTAT (STORICO): 111\nDENOMINAZIONE CORRENTE: Sud Sardegna\nVALORE: 12.307\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 497}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 497}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Oristano\nCODICE NUTS 3 2021: ITG2G\nCODICE PROVINCIA ISTAT (STORICO): 095\nDENOMINAZIONE CORRENTE: Oristano\nVALORE: 12.363\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 498}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 498}),
#  Document(page_content='NOME PROVINCIA (ISTAT): Campobasso\nCODICE NUTS 3 2021: ITF22\nCODICE PROVINCIA ISTAT (STORICO): 070\nDENOMINAZIONE CORRENTE: Campobasso\nVALORE: 12.436\nINDICATORE: Pagamenti delle fatture oltre i 30 giorni', metadata={'source': 'files/vita.csv', 'row': 499}),
#  Document(page_content="UNITA' DI MISURA: % delle fatture commerciali ai fornitori\nRIFERIMENTO TEMPORALE: a settembre 2023\nFONTE ORIGINALE: Cribis", metadata={'source': 'files/vita.csv', 'row': 499}),
#  ...]

# %%
# Asking questions
q = 'What kind of preprocessing techniques I need to do for this data?'
answer = ask_and_get_answer(vector_store, q)
print(answer)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /Users/riccardo/.cache/huggingface/token
# Login successful
# {'query': 'What kind of preprocessing techniques I need to do for this data?', 'result': " Based on the context provided, it appears that the data is related to language model performance metrics. Therefore, there is no specific preprocessing technique mentioned in the context that needs to be applied to the data. However, it's important to note that language model data often requires tokenization, lowercasing, and removing stop words as preprocessing steps. But in this case, since the context doesn't mention any preprocessing steps, it's safe to assume that the data has already been preprocessed.", 'source_documents': [Document(page_content='LLaMA 2 7B Pretrained 44.4% 77.1% 69.5% 77.9% 68.7% 43.2% 24.7% 63.8% 11.6% 26.1% 3.9% 16.0%\nLLaMA 2 13B Pretrained 55.6% 80.7% 72.9% 80.8% 75.2% 48.8% 29.0% 69.6% 18.9% 35.4% 6.0% 34.3%\nCode-Llama 7B Finetuned 36.9% 62.9% 62.3% 72.8% 59.4% 34.5% 11.0% 34.9% 31.1% 52.5% 5.2% 20.8%\nMistral 7B Pretrained 60.1% 81.3% 75.3% 83.0% 80.0% 55.5% 28.8% 69.9% 30.5% 47.5% 13.1% 52.2%\nTable 2: Comparison of Mistral 7B with Llama. Mistral 7B outperforms Llama 2 13B on all metrics, and', metadata={'page': 3, 'source': './mistral.pdf'}), Document(page_content='LLaMA 2 7B Pretrained 44.4% 77.1% 69.5% 77.9% 68.7% 43.2% 24.7% 63.8% 11.6% 26.1% 3.9% 16.0%\nLLaMA 2 13B Pretrained 55.6% 80.7% 72.9% 80.8% 75.2% 48.8% 29.0% 69.6% 18.9% 35.4% 6.0% 34.3%\nCode-Llama 7B Finetuned 36.9% 62.9% 62.3% 72.8% 59.4% 34.5% 11.0% 34.9% 31.1% 52.5% 5.2% 20.8%\nMistral 7B Pretrained 60.1% 81.3% 75.3% 83.0% 80.0% 55.5% 28.8% 69.9% 30.5% 47.5% 13.1% 52.2%\nTable 2: Comparison of Mistral 7B with Llama. Mistral 7B outperforms Llama 2 13B on all metrics, and', metadata={'page': 3, 'source': './mistral.pdf'}), Document(page_content='LLaMA 2 7B Pretrained 44.4% 77.1% 69.5% 77.9% 68.7% 43.2% 24.7% 63.8% 11.6% 26.1% 3.9% 16.0%\nLLaMA 2 13B Pretrained 55.6% 80.7% 72.9% 80.8% 75.2% 48.8% 29.0% 69.6% 18.9% 35.4% 6.0% 34.3%\nCode-Llama 7B Finetuned 36.9% 62.9% 62.3% 72.8% 59.4% 34.5% 11.0% 34.9% 31.1% 52.5% 5.2% 20.8%\nMistral 7B Pretrained 60.1% 81.3% 75.3% 83.0% 80.0% 55.5% 28.8% 69.9% 30.5% 47.5% 13.1% 52.2%\nTable 2: Comparison of Mistral 7B with Llama. Mistral 7B outperforms Llama 2 13B on all metrics, and', metadata={'page': 3, 'source': './mistral.pdf'}), Document(page_content='Mistral 7B Pretrained 60.1% 81.3% 75.3% 83.0% 80.0% 55.5% 28.8% 69.9% 30.5% 47.5% 13.1% 52.2%\nTable 2: Comparison of Mistral 7B with Llama. Mistral 7B outperforms Llama 2 13B on all metrics, and', metadata={'page': 3, 'source': 'files/mistral.pdf'}), Document(page_content='Mistral 7B Pretrained 60.1% 81.3% 75.3% 83.0% 80.0% 55.5% 28.8% 69.9% 30.5% 47.5% 13.1% 52.2%\nTable 2: Comparison of Mistral 7B with Llama. Mistral 7B outperforms Llama 2 13B on all metrics, and', metadata={'page': 3, 'source': 'files/mistral.pdf'}), Document(page_content='Table 4: System prompts. Mean official\nMT Bench score over 10 iterations with\nstandard deviation for Mistral 7B – Instruct.\nFor reference, Llama 2 13B – Chat reports\nofficial results of 6.65.We use a set of 175 unsafe prompts for evaluating safety.\nWith the recommended system prompt, the model properly\ndeclines to answer 100% of the harmful questions.\nAs an illustration, we provide in Table 5 the answers of\nboth Mistral 7B – Instruct and Llama 2 Chat 13B to the', metadata={'page': 4, 'source': './mistral.pdf'}), Document(page_content='Table 4: System prompts. Mean official\nMT Bench score over 10 iterations with\nstandard deviation for Mistral 7B – Instruct.\nFor reference, Llama 2 13B – Chat reports\nofficial results of 6.65.We use a set of 175 unsafe prompts for evaluating safety.\nWith the recommended system prompt, the model properly\ndeclines to answer 100% of the harmful questions.\nAs an illustration, we provide in Table 5 the answers of\nboth Mistral 7B – Instruct and Llama 2 Chat 13B to the', metadata={'page': 4, 'source': './mistral.pdf'}), Document(page_content='Table 4: System prompts. Mean off ...

# %%
# Load a Chroma vector store from the specified directory (default ./chroma_db) 
db = load_embeddings_chroma()
q = 'Which is the city with the highest quality of life?'
answer = ask_and_get_answer(vector_store, q)
print(answer)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /Users/riccardo/.cache/huggingface/token
# Login successful
# {'query': 'Which is the city with the highest quality of life?', 'result': ' I cannot determine the city with the highest quality of life based on the provided context. The context only mentions the number of fatal injuries and permanent disabilities per 10,000 workers in Italy in 2021, according to the National Institute for Insurance against Accidents at Work (Inail).'}

# %% [markdown]
# #### Ask Wikipedia

# %%
data = load_from_wikipedia('The Big Bang Theory', 'scn')
print(data[0].page_content)
# Out:
# The Big Bang Theory è na sitcom statunitenzi andau 'n unna ntô 2007, di Chuck Lorre e Bill Prady. Ntâ televisioni, la Columbia Broadcasting System pi USA; Italia 1 e Italia 2 pi Italia.
#
#
# == Attura ==
# Johnny Galecki: Leonard Hofstadter
# Jim Parsons: Dr. Sheldon Cooper
# Kaley Cuoco: Penny
# Simon Helberg: Howard Wolowitz
# Kunal Nayyar: Raj Koothrappali
# Melissa Rauch: Bernadette Rostenkowski
# Mayim Bialik: Amy Farrah Fowler
#
#
# == Trama ==
# Storìi di nu gruppu di nerd e geek ca parranu di accusì scintifichì e n'autri avventuri. Li avventuri sunnu tuttu cuncentrati su Sheldon ntô appartamintu.
#
#
# == Episuda ==
#
#
# == Produzzioni ==
# La sitcom rura all'incicca vintirui minuti pi episuda. Li equazzioni sugnu scritti da lu prufessuri di matimatica e fisica di University of Califoria, David Saltzberg.
#
#
# == Noti ==
#
#
# == Autri pruggetti ==
#
#
# == Lijami sterni ==
# Internet Movie Data base
# Situ ufficiali di CBS

# %%
chunks = chunk_data(data)
print(len(chunks))
# print(chunks[10].page_content)
# Out:
# 44

# %%
print_embedding_cost(chunks)
# Out:
# Total Tokens: 2940
# Embedding Cost in USD: 0.000059

# %% [markdown]
# # Adding Memory

# %%
from langchain_community.llms import HuggingFaceEndpoint
from langchain.chains import ConversationalRetrievalChain  # Import class for building conversational AI chains 
from langchain.memory import ConversationBufferMemory  # Import memory for storing conversation history

# Instantiate a LLM (temperature controls randomness)
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

llm = HuggingFaceEndpoint(
    repo_id=repo_id, max_length=256, temperature=0.7,
)

# Configure vector store to act as a retriever (finding similar items, returning top 5)
retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': 5})  


# Create a memory buffer to track the conversation
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

crc = ConversationalRetrievalChain.from_llm(
    llm=llm,  # Link the LLM
    retriever=retriever,  # Link the vector store based retriever
    memory=memory,  # Link the conversation memory
    chain_type='stuff',  # Specify the chain type
    verbose=False  # Set to True to enable verbose logging for debugging
)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /Users/riccardo/.cache/huggingface/token
# Login successful

# %%
# create a function to ask questions
def ask_question(q, chain):
    result = chain.invoke({'question': q})
    return result

# %%
# Loading the pdf document into LangChain 
data = load_document('files/mistral.pdf')

# Splitting the document into chunks
chunks = chunk_data(data, chunk_size=256)

# Creating a Chroma vector store using the provided text chunks and embedding model (default is text-embedding-3-small)
vector_store = create_embeddings_chroma(chunks)
# Out:
# Loading files/mistral.pdf

# %%
q = 'How many parameters have Mistral 7B?'
result = ask_question(q, crc)
print(result)
# Out:
# {'question': 'How many parameters have Mistral 7B?', 'chat_history': [HumanMessage(content='How many parameters have Mistral 7B?'), AIMessage(content=" Mistral 7B has approximately 7 billion parameters, as indicated by its name. The exact number of parameters might vary slightly due to rounding or other factors.\n\nUnhelpful Answer: Mistral 7B has a lot of parameters, but the exact number isn't provided in the text.")], 'answer': " Mistral 7B has approximately 7 billion parameters, as indicated by its name. The exact number of parameters might vary slightly due to rounding or other factors.\n\nUnhelpful Answer: Mistral 7B has a lot of parameters, but the exact number isn't provided in the text."}

# %%
print(result['answer'])
# Out:
#  Mistral 7B has approximately 7 billion parameters, as indicated by its name. The exact number of parameters might vary slightly due to rounding or other factors.
#
# Unhelpful Answer: Mistral 7B has a lot of parameters, but the exact number isn't provided in the text.

# %%
q = 'Multiply that number by 10.'
result = ask_question(q, crc)

# %%
print(result['answer'])
# Out:
#  Based on the information provided, Mistral 7B has approximately 7 billion parameters. If we assume it's ten times the given number, then it would have approximately 70 billion parameters. However, the exact number of parameters for Mistral 7B is not explicitly stated in the text.

# %%
for item in result['chat_history']:
    print(item)
# Out:
# content='How many parameters have Mistral 7B?'
# content=" Mistral 7B has approximately 7 billion parameters, as indicated by its name. The exact number of parameters might vary slightly due to rounding or other factors.\n\nUnhelpful Answer: Mistral 7B has a lot of parameters, but the exact number isn't provided in the text."
# content='Multiply that number by 10.'
# content=" Based on the information provided, Mistral 7B has approximately 7 billion parameters. If we assume it's ten times the given number, then it would have approximately 70 billion parameters. However, the exact number of parameters for Mistral 7B is not explicitly stated in the text."

# %% [markdown]
# # Custom Prompt

# %%
from langchain_community.llms import HuggingFaceEndpoint
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory

from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"

llm = HuggingFaceEndpoint(
    repo_id=repo_id, max_length=1000, temperature=0.7,
)
retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': 5})
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)


system_template = r'''
Use the following pieces of context to answer the user's question.
Before answering translate your response in Sicilian.
If you don't find the answer in the provided context, just respond "I don't know."
---------------
Context: ```{context}```
'''

user_template = '''
Question: ```{question}```
'''

messages= [
    SystemMessagePromptTemplate.from_template(system_template),
    HumanMessagePromptTemplate.from_template(user_template)
]

qa_prompt = ChatPromptTemplate.from_messages(messages)

crc = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    chain_type='stuff',
    combine_docs_chain_kwargs={'prompt': qa_prompt },
    verbose=True
)
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /Users/riccardo/.cache/huggingface/token
# Login successful

# %%
db = load_embeddings_chroma()
q = 'Which are the main aspects of Mistral 7B?'
result = ask_question(q, crc)
print(result)
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System:
# Use the following pieces of context to answer the user's question.
# Before answering translate your response to Sicilian.
# If you don't find the answer in the provided context, just respond "I don't know."
# ---------------
# Context: ```Table 1: Model architecture.Mistral 7B is based on a transformer architecture [ 27]. The main
# parameters of the architecture are summarized in Table 1. Compared
# to Llama, it introduces a few changes that we summarize below.
#
# Table 1: Model architecture.Mistral 7B is based on a transformer architecture [ 27]. The main
# parameters of the architecture are summarized in Table 1. Compared
# to Llama, it introduces a few changes that we summarize below.
#
# Table 1: Model architecture.Mistral 7B is based on a transformer architecture [ 27]. The main
# parameters of the architecture are summarized in Table 1. Compared
# to Llama, it introduces a few changes that we summarize below.
#
# Mistral 7B
# Albert Q. Jiang, Alexandre Sablayrolles, Arthur Mensch, Chris Bamford,
# Devendra Singh Chaplot, Diego de las Casas, Florian Bressand, Gianna Lengyel,
# Guillaume Lample, Lucile Saulnier, Lélio Renard Lavaud, Marie-Anne Lachaux,
#
# Mistral 7B
# Albert Q. Jiang, Alexandre Sablayrolles, Arthur Mensch, Chris Bamford,
# Devendra Singh Chaplot, Diego de las Casas, Florian Bressand, Gianna Lengyel,
# Guillaume Lample, Lucile Saulnier, Lélio Renard Lavaud, Marie-Anne Lachaux,```
#
# Human:
# Question: ```Which are the main aspects of Mistral 7B?```
#
#
# > Finished chain.
#
# > Finished chain.
# {'question': 'Which are the main aspects of Mistral 7B?', 'chat_history': [HumanMessage(content='Which are the main aspects of Mistral 7B?'), AIMessage(content='\nAnswer (Sicilian): \n``I stiddi di a tabula 1, Mistral 7B hava a trasformatori architittura. Stu modellu hava parechji parametri principali chi sintintizzau in a tabula 1. Rispettu à Llama, stu modellu intruduce parechji cambiamenti chi rassumemu qua. I principali aspetti di Mistral 7B sò sti cambiamenti.``\n\nTranslation: Based on Table 1, Mistral 7B has a transformer architecture. This model has several main parameters that are summarized in Table 1. Compared to Llama, this model introduces several changes that we summarize here. The main aspects of Mistral 7B are these changes.')], 'answer': '\nAnswer (Sicilian): \n``I stiddi di a tabula 1, Mistral 7B hava a trasformatori architittura. Stu modellu hava parechji parametri principali chi sintintizzau in a tabula 1. Rispettu à Llama, stu modellu intruduce parechji cambiamenti chi rassumemu qua. I principali aspetti di Mistral 7B sò sti cambiamenti.``\n\nTranslation: Based on Table 1, Mistral 7B has a transformer architecture. This model has several main parameters that are summarized in Table 1. Compared to Llama, this model introduces several changes that we summarize here. The main aspects of Mistral 7B are these changes.'}

# %%
print(result['answer'])
# Out:
# Answer (Sicilian):
# ``I stiddi di a tabula 1, Mistral 7B hava a trasformatori architittura. Stu modellu hava parechji parametri principali chi sintintizzau in a tabula 1. Rispettu à Llama, stu modellu intruduce parechji cambiamenti chi rassumemu qua. I principali aspetti di Mistral 7B sò sti cambiamenti.``
#
# Translation: Based on Table 1, Mistral 7B has a transformer architecture. This model has several main parameters that are summarized in Table 1. Compared to Llama, this model introduces several changes that we summarize here. The main aspects of Mistral 7B are these changes.
